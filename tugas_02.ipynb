# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data_kki.csv', sep=';')

data['Prodi'].value_counts().plot(kind='pie')
plt.savefig('python_pie')

plt.close()

data['Prodi'].value_counts().plot(kind='bar')
plt.savefig('python_bar')
